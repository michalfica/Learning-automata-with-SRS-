# %%
import copy, sys, pandas as pd
import random
import time
import numpy as np
import subprocess 

sys.path.append("../../")
sys.path.append("../../inferring")
sys.path.append("../../utils/DFA")
from importlib import reload


import inferring.Inferring as Inferring, inferring.InferringDFA as InferringDFA
import utils.automats.DFA
import utils.advice_systems.SRS as SRS

reload(SRS)
reload(Inferring)
reload(InferringDFA)
reload(utils.automats.DFA)

from inferring.Inferring import Inferring
from utils.automats.DFA.DFA import DFA
from utils.advice_systems.SRS import SRS

from inferring.InferringDFA import InferringDFA

# %%
def run_learning_process(target, advice_system=None, check_consistency=False, equiv_query_fashion="BFS", debug=False):
    _dfa = copy.deepcopy(target)
    learn_dfa = InferringDFA(_dfa, 
                                advice_system, 
                                check_consistency=check_consistency, 
                                equiv_query_fashion=equiv_query_fashion,
                                debug=debug)
        
    dfa, cnt, cnt_ex = learn_dfa.run(counterexamples=True)
    return copy.deepcopy(dfa), cnt, len(cnt_ex) +1

# %%
class Record:

    def __init__(self,
                 d1,
                 d2,
                 conv,
                 lstar_with_advice,
                 target=None,
                 ttt_eq=None, 
                 ttt_wa_eq=None):
        self.d1 = d1
        self.d2 = d2
        self.conv = conv
        self.lstar_with_advice = lstar_with_advice
        self.ttt_eq = ttt_eq
        self.ttt_wa_eq = ttt_wa_eq 
        self.target = target

    def print_record(self):
        print(
            f"|d1| = {self.d1}, |d2| = {self.d2}, |conv| = {self.conv}, (mq, eq) = {self.lstar_with_advice}"
        )
    def get_complete_description(self):
        return self.target.print_complete_description()
    
    def print_target(self):
        print(self.target.print_complete_description())

# %%
def getNumberofEQ(s):
    for l in s.splitlines():
        if l.startswith("Learning rounds"):
            return l.split()[-1]

# %%
"""
    Files TTTExample1.java and TTTExample1_withAS.java should be placed in the following directory: examples/src/main/java/de/learnlib/example
    Before executing TTTExample1.java file build learlib project:                                   mvn clean install 
"""


number_of_itreations = 65

#  Fixed random seeds for reproducibility
seeds = [i for i in range(number_of_itreations)]

# The alphabet of the DFA
input_signs = ["a", "b", "c"]

# The bound on the number of states
max_number_of_states = 40

# The list to aggregate the results
results = []

_ = subprocess.run(["cd ../../../learnlib/examples ; mvn clean install; cd ../../magisterka/test_algorithm/TTT"], shell=True, capture_output=True, text=True)
i = 0
while i < number_of_itreations:
    random.seed(seeds[i])
    i += 1
    print(f"iter nr: {i}")

    # Create two random DFAs
    dfa1 = DFA()
    dfa2 = DFA()
    dfa1.create_random_dfa(
        Q=random.randint(max_number_of_states // 2, max_number_of_states),
        input_signs=input_signs,
    )
    dfa2.create_random_dfa(
        Q=random.randint(max_number_of_states // 2, max_number_of_states),
        input_signs=input_signs,
    )

    # Run learning of the language of DFA to minimize dfa1 and dfa2
    d1, _, _ = run_learning_process(target=copy.deepcopy(dfa1))
    d2, _, _ = run_learning_process(target=copy.deepcopy(dfa2))

    if d1.Q < 2 or d2.Q < 2:
        continue
        # Create two random DFAs
        dfa1 = DFA()
        dfa2 = DFA()
        dfa1.create_random_dfa(
            Q=random.randint(max_number_of_states // 2, max_number_of_states),
            input_signs=input_signs,
        )
        dfa2.create_random_dfa(
            Q=random.randint(max_number_of_states // 2, max_number_of_states),
            input_signs=input_signs,
        )

        # Run learning of the language of DFA to minimize dfa1 and dfa2
        d1, _, _ = run_learning_process(target=copy.deepcopy(dfa1))
        d2, _, _ = run_learning_process(target=copy.deepcopy(dfa2))

    # Create a convolution DFA based on d1 and d2
    conv_dfa = DFA()
    conv_dfa.create_convolution(dfa1=d1, dfa2=d2)

    # Learn conv_dfa with advice, and store d - learned automaton 
    start_t = time.time()
    d, lstar_with_advice, lstar_ex_with_advice = run_learning_process(
        target=conv_dfa, advice_system=SRS(), check_consistency=True
    )
    end_t = time.time()

    print("ex time with AS: ", end_t - start_t)
    print(f"|d1.Q| = {d1.Q}, |d2.q| = {d2.Q}, |d.Q| = {d.Q}")
    d.type = DFA.CONV_DFA

    results.append(
        Record(
            d1=d1.Q,
            d2=d2.Q,
            conv=d.Q,
            lstar_with_advice=(lstar_with_advice, lstar_ex_with_advice),
            target=copy.deepcopy(d),
        )
    )
    results[-1].print_record()
    f = open("../../../learnlib/examples/src/main/java/de/learnlib/example/DfaEx" + ".txt", "w")
    f.write(results[-1].get_complete_description())
    f.close()

    ttt_output = subprocess.run(["cd ../../../learnlib/examples ; mvn exec:java -q -Dexec.mainClass=\"de.learnlib.example.TTTExample1\" ; cd ../../magisterka/test_algorithm/TTT"], shell=True, capture_output=True, text=True)
    print("TTT done")
    ttt_wa_output = subprocess.run(["cd ../../../learnlib/examples ; mvn exec:java -q -Dexec.mainClass=\"de.learnlib.example.TTTExample1_withAS\" ; cd ../../magisterka/test_algorithm/TTT"], shell=True, capture_output=True, text=True)
    print("TTT with AS done")

    results[-1].ttt_eq = int(getNumberofEQ(ttt_output.stdout))
    results[-1].ttt_wa_eq = int(getNumberofEQ(ttt_wa_output.stdout))
# Out:
# iter nr: 1
# ex time with AS:  60.76960778236389
# |d1.Q| = 30, |d2.q| = 33, |d.Q| = 990
# |d1| = 30, |d2| = 33, |conv| = 990, (mq, eq) = ([519133, 2], 160)
# TTT done
# TTT with AS done
# iter nr: 2
# ex time with AS:  12.416016340255737
# |d1.Q| = 22, |d2.q| = 23, |d.Q| = 506
# |d1| = 22, |d2| = 23, |conv| = 506, (mq, eq) = ([160267, 2], 92)
# TTT done
# TTT with AS done
# iter nr: 3
# iter nr: 4
# ex time with AS:  68.86998796463013
# |d1.Q| = 26, |d2.q| = 37, |d.Q| = 962
# |d1| = 26, |d2| = 37, |conv| = 962, (mq, eq) = ([517356, 3], 165)
# TTT done
# TTT with AS done
# iter nr: 5
# ex time with AS:  22.589881896972656
# |d1.Q| = 27, |d2.q| = 25, |d.Q| = 675
# |d1| = 27, |d2| = 25, |conv| = 675, (mq, eq) = ([237219, 2], 106)
# TTT done
# TTT with AS done
# iter nr: 6
# ex time with AS:  244.95925116539001
# |d1.Q| = 37, |d2.q| = 38, |d.Q| = 1406
# |d1| = 37, |d2| = 38, |conv| = 1406, (mq, eq) = ([1215106, 2], 262)
# TTT done
# TTT with AS done
# iter nr: 7
# ex time with AS:  114.02470302581787
# |d1.Q| = 37, |d2.q| = 30, |d.Q| = 1110
# |d1| = 37, |d2| = 30, |conv| = 1110, (mq, eq) = ([716773, 2], 199)
# TTT done
# TTT with AS done
# iter nr: 8
# ex time with AS:  43.021193504333496
# |d1.Q| = 27, |d2.q| = 31, |d.Q| = 837
# |d1| = 27, |d2| = 31, |conv| = 837, (mq, eq) = ([344839, 3], 122)
# TTT done
# TTT with AS done
# iter nr: 9
# iter nr: 10
# ex time with AS:  34.45932483673096
# |d1.Q| = 32, |d2.q| = 23, |d.Q| = 736
# |d1| = 32, |d2| = 23, |conv| = 736, (mq, eq) = ([330210, 3], 136)
# TTT done
# TTT with AS done
# iter nr: 11
# ex time with AS:  73.87624835968018
# |d1.Q| = 35, |d2.q| = 38, |d.Q| = 1330
# |d1| = 35, |d2| = 38, |conv| = 1330, (mq, eq) = ([604704, 2], 141)
# TTT done
# TTT with AS done
# iter nr: 12
# ex time with AS:  62.454615116119385
# |d1.Q| = 29, |d2.q| = 37, |d.Q| = 1073
# |d1| = 29, |d2| = 37, |conv| = 1073, (mq, eq) = ([492468, 3], 141)
# TTT done
# TTT with AS done
# iter nr: 13
# ex time with AS:  608.7852692604065
# |d1.Q| = 35, |d2.q| = 37, |d.Q| = 1295
# |d1| = 35, |d2| = 37, |conv| = 1295, (mq, eq) = ([1774438, 8], 459)
# TTT done
# TTT with AS done
# iter nr: 14
# ex time with AS:  57.45339512825012
# |d1.Q| = 25, |d2.q| = 35, |d.Q| = 875
# |d1| = 25, |d2| = 35, |conv| = 875, (mq, eq) = ([439048, 2], 152)
# TTT done
# TTT with AS done
# iter nr: 15
# iter nr: 16
# ex time with AS:  77.07375693321228
# |d1.Q| = 25, |d2.q| = 34, |d.Q| = 850
# |d1| = 25, |d2| = 34, |conv| = 850, (mq, eq) = ([544410, 2], 187)
# TTT done
# TTT with AS done
# iter nr: 17
# ex time with AS:  36.37879180908203
# |d1.Q| = 24, |d2.q| = 37, |d.Q| = 888
# |d1| = 24, |d2| = 37, |conv| = 888, (mq, eq) = ([351006, 2], 117)
# TTT done
# TTT with AS done
# iter nr: 18
# ex time with AS:  33.72153854370117
# |d1.Q| = 33, |d2.q| = 26, |d.Q| = 858
# |d1| = 33, |d2| = 26, |conv| = 858, (mq, eq) = ([354687, 2], 117)
# TTT done
# TTT with AS done
# iter nr: 19
# ex time with AS:  37.94025015830994
# |d1.Q| = 23, |d2.q| = 22, |d.Q| = 506
# |d1| = 23, |d2| = 22, |conv| = 506, (mq, eq) = ([286926, 5], 184)
# TTT done
# TTT with AS done
# iter nr: 20
# ex time with AS:  8.69514536857605
# |d1.Q| = 19, |d2.q| = 25, |d.Q| = 475
# |d1| = 19, |d2| = 25, |conv| = 475, (mq, eq) = ([139561, 2], 80)
# TTT done
# TTT with AS done
# iter nr: 21
# iter nr: 22
# ex time with AS:  76.61733198165894
# |d1.Q| = 24, |d2.q| = 37, |d.Q| = 888
# |d1| = 24, |d2| = 37, |conv| = 888, (mq, eq) = ([553442, 7], 185)
# TTT done
# TTT with AS done
# iter nr: 23
# ex time with AS:  7.517308235168457
# |d1.Q| = 22, |d2.q| = 21, |d.Q| = 462
# |d1| = 22, |d2| = 21, |conv| = 462, (mq, eq) = ([116651, 1], 74)
# TTT done
# TTT with AS done
# iter nr: 24
# ex time with AS:  80.26834034919739
# |d1.Q| = 29, |d2.q| = 29, |d.Q| = 841
# |d1| = 29, |d2| = 29, |conv| = 841, (mq, eq) = ([501591, 3], 189)
# TTT done
# TTT with AS done
# iter nr: 25
# iter nr: 26
# ex time with AS:  11.993706464767456
# |d1.Q| = 29, |d2.q| = 18, |d.Q| = 522
# |d1| = 29, |d2| = 18, |conv| = 522, (mq, eq) = ([168296, 1], 92)
# TTT done
# TTT with AS done
# iter nr: 27
# ex time with AS:  9.639306545257568
# |d1.Q| = 24, |d2.q| = 20, |d.Q| = 480
# |d1| = 24, |d2| = 20, |conv| = 480, (mq, eq) = ([149687, 1], 90)
# TTT done
# TTT with AS done
# iter nr: 28
# ex time with AS:  43.669177770614624
# |d1.Q| = 37, |d2.q| = 25, |d.Q| = 925
# |d1| = 37, |d2| = 25, |conv| = 925, (mq, eq) = ([393110, 2], 127)
# TTT done
# TTT with AS done
# iter nr: 29
# ex time with AS:  12.871410608291626
# |d1.Q| = 23, |d2.q| = 27, |d.Q| = 621
# |d1| = 23, |d2| = 27, |conv| = 621, (mq, eq) = ([174521, 3], 79)
# TTT done
# TTT with AS done
# iter nr: 30
# iter nr: 31
# ex time with AS:  128.66949558258057
# |d1.Q| = 37, |d2.q| = 33, |d.Q| = 1221
# |d1| = 37, |d2| = 33, |conv| = 1221, (mq, eq) = ([785252, 2], 193)
# TTT done
# TTT with AS done
# iter nr: 32
# ex time with AS:  18.8980495929718
# |d1.Q| = 19, |d2.q| = 29, |d.Q| = 551
# |d1| = 19, |d2| = 29, |conv| = 551, (mq, eq) = ([184194, 2], 99)
# TTT done
# TTT with AS done
# iter nr: 33
# ex time with AS:  35.01201057434082
# |d1.Q| = 18, |d2.q| = 31, |d.Q| = 558
# |d1| = 18, |d2| = 31, |conv| = 558, (mq, eq) = ([293540, 3], 151)
# TTT done
# TTT with AS done
# iter nr: 34
# ex time with AS:  48.24822998046875
# |d1.Q| = 36, |d2.q| = 20, |d.Q| = 720
# |d1| = 36, |d2| = 20, |conv| = 720, (mq, eq) = ([404663, 4], 157)
# TTT done
# TTT with AS done
# iter nr: 35
# iter nr: 36
# ex time with AS:  105.37151598930359
# |d1.Q| = 34, |d2.q| = 36, |d.Q| = 1224
# |d1| = 34, |d2| = 36, |conv| = 1224, (mq, eq) = ([683037, 2], 171)
# TTT done
# TTT with AS done
# iter nr: 37
# ex time with AS:  17.900511741638184
# |d1.Q| = 29, |d2.q| = 22, |d.Q| = 638
# |d1| = 29, |d2| = 22, |conv| = 638, (mq, eq) = ([206523, 2], 96)
# TTT done
# TTT with AS done
# iter nr: 38
# ex time with AS:  35.33511209487915
# |d1.Q| = 38, |d2.q| = 22, |d.Q| = 836
# |d1| = 38, |d2| = 22, |conv| = 836, (mq, eq) = ([316523, 1], 115)
# TTT done
# TTT with AS done
# iter nr: 39
# ex time with AS:  108.29978847503662
# |d1.Q| = 39, |d2.q| = 36, |d.Q| = 1404
# |d1| = 39, |d2| = 36, |conv| = 1404, (mq, eq) = ([777631, 3], 173)
# TTT done
# TTT with AS done
# iter nr: 40
# ex time with AS:  33.5508770942688
# |d1.Q| = 25, |d2.q| = 35, |d.Q| = 875
# |d1| = 25, |d2| = 35, |conv| = 875, (mq, eq) = ([328645, 2], 114)
# TTT done
# TTT with AS done
# iter nr: 41
# ex time with AS:  8.741325378417969
# |d1.Q| = 33, |d2.q| = 19, |d.Q| = 627
# |d1| = 33, |d2| = 19, |conv| = 627, (mq, eq) = ([149512, 2], 64)
# TTT done
# TTT with AS done
# iter nr: 42
# ex time with AS:  54.85419583320618
# |d1.Q| = 30, |d2.q| = 28, |d.Q| = 840
# |d1| = 30, |d2| = 28, |conv| = 840, (mq, eq) = ([405508, 2], 153)
# TTT done
# TTT with AS done
# iter nr: 43
# ex time with AS:  33.50924587249756
# |d1.Q| = 36, |d2.q| = 22, |d.Q| = 792
# |d1| = 36, |d2| = 22, |conv| = 792, (mq, eq) = ([330340, 4], 125)
# TTT done
# TTT with AS done
# iter nr: 44
# iter nr: 45
# ex time with AS:  22.029021501541138
# |d1.Q| = 27, |d2.q| = 29, |d.Q| = 783
# |d1| = 27, |d2| = 29, |conv| = 783, (mq, eq) = ([268595, 4], 100)
# TTT done
# TTT with AS done
# iter nr: 46
# ex time with AS:  23.744863748550415
# |d1.Q| = 25, |d2.q| = 25, |d.Q| = 625
# |d1| = 25, |d2| = 25, |conv| = 625, (mq, eq) = ([258130, 2], 117)
# TTT done
# TTT with AS done
# iter nr: 47
# ex time with AS:  17.560072898864746
# |d1.Q| = 22, |d2.q| = 31, |d.Q| = 682
# |d1| = 22, |d2| = 31, |conv| = 682, (mq, eq) = ([219751, 3], 90)
# TTT done
# TTT with AS done
# iter nr: 48
# ex time with AS:  87.69834780693054
# |d1.Q| = 30, |d2.q| = 35, |d.Q| = 1050
# |d1| = 30, |d2| = 35, |conv| = 1050, (mq, eq) = ([610535, 2], 180)
# TTT done
# TTT with AS done
# iter nr: 49
# ex time with AS:  64.2044906616211
# |d1.Q| = 36, |d2.q| = 20, |d.Q| = 720
# |d1| = 36, |d2| = 20, |conv| = 720, (mq, eq) = ([456388, 4], 194)
# TTT done
# TTT with AS done
# iter nr: 50
# ex time with AS:  21.83268713951111
# |d1.Q| = 21, |d2.q| = 39, |d.Q| = 819
# |d1| = 21, |d2| = 39, |conv| = 819, (mq, eq) = ([264045, 1], 97)
# TTT done
# TTT with AS done
# iter nr: 51
# ex time with AS:  46.958515882492065
# |d1.Q| = 32, |d2.q| = 31, |d.Q| = 992
# |d1| = 32, |d2| = 31, |conv| = 992, (mq, eq) = ([439646, 2], 138)
# TTT done
# TTT with AS done
# iter nr: 52
# ex time with AS:  34.618985176086426
# |d1.Q| = 25, |d2.q| = 35, |d.Q| = 875
# |d1| = 25, |d2| = 35, |conv| = 875, (mq, eq) = ([347848, 2], 118)
# TTT done
# TTT with AS done
# iter nr: 53
# ex time with AS:  37.67249608039856
# |d1.Q| = 26, |d2.q| = 30, |d.Q| = 780
# |d1| = 26, |d2| = 30, |conv| = 780, (mq, eq) = ([359189, 3], 139)
# TTT done
# TTT with AS done
# iter nr: 54
# ex time with AS:  239.82892417907715
# |d1.Q| = 37, |d2.q| = 36, |d.Q| = 1332
# |d1| = 37, |d2| = 36, |conv| = 1332, (mq, eq) = ([1070417, 6], 258)
# TTT done
# TTT with AS done
# iter nr: 55
# ex time with AS:  48.69910216331482
# |d1.Q| = 24, |d2.q| = 38, |d.Q| = 912
# |d1| = 24, |d2| = 38, |conv| = 912, (mq, eq) = ([390379, 2], 131)
# TTT done
# TTT with AS done
# iter nr: 56
# ex time with AS:  14.62923002243042
# |d1.Q| = 22, |d2.q| = 26, |d.Q| = 572
# |d1| = 22, |d2| = 26, |conv| = 572, (mq, eq) = ([186316, 1], 96)
# TTT done
# TTT with AS done
# iter nr: 57
# iter nr: 58
# ex time with AS:  10.270071268081665
# |d1.Q| = 19, |d2.q| = 27, |d.Q| = 513
# |d1| = 19, |d2| = 27, |conv| = 513, (mq, eq) = ([139282, 2], 79)
# TTT done
# TTT with AS done
# iter nr: 59
# ex time with AS:  103.95943236351013
# |d1.Q| = 36, |d2.q| = 35, |d.Q| = 1260
# |d1| = 36, |d2| = 35, |conv| = 1260, (mq, eq) = ([727147, 4], 175)
# TTT done
# TTT with AS done
# iter nr: 60
# ex time with AS:  51.107972145080566
# |d1.Q| = 25, |d2.q| = 26, |d.Q| = 650
# |d1| = 25, |d2| = 26, |conv| = 650, (mq, eq) = ([359918, 4], 184)
# TTT done
# TTT with AS done
# iter nr: 61
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 68
#      66 # Learn conv_dfa with advice, and store d - learned automaton
#      67 start_t = time.time()
# ---> 68 d, lstar_with_advice, lstar_ex_with_advice = run_learning_process(
#      69     target=conv_dfa, advice_system=SRS(), check_consistency=True
#      70 )
#      71 end_t = time.time()
#      73 print("ex time with AS: ", end_t - start_t)
#
# Cell In[2], line 9, in run_learning_process(target, advice_system, check_consistency, equiv_query_fashion, debug)
#       2 _dfa = copy.deepcopy(target)
#       3 learn_dfa = InferringDFA(_dfa,
#       4                             advice_system,
#       5                             check_consistency=check_consistency,
#       6                             equiv_query_fashion=equiv_query_fashion,
#       7                             debug=debug)
# ----> 9 dfa, cnt, cnt_ex = learn_dfa.run(counterexamples=True)
#      10 return copy.deepcopy(dfa), cnt, len(cnt_ex) +1
#
# File ~/Documents/edu/studia2/magisterka/test_algorithm/TTT/../../inferring/Inferring.py:105, in Inferring.run(self, counterexamples, return_srs_size)
#     102     self._extend_S(x)
#     103     check, x, last_checked = self._closed(start_index=last_checked)
# --> 105 conjecture = self._create_conjecture()
#     106 if self.debug:
#     107     print(f"new candidate created: {conjecture.Q}")
#
# File ~/Documents/edu/studia2/magisterka/test_algorithm/TTT/../../inferring/InferringDFA.py:116, in InferringDFA._create_conjecture(self)
#     115 def _create_conjecture(self):
# --> 116     return copy.deepcopy(self._create_automat())
#
# File ~/Documents/edu/studia2/magisterka/test_algorithm/TTT/../../inferring/InferringDFA.py:109, in InferringDFA._create_automat(self, _type)
#     107 conjecture.mapping[i] = s
#     108 for a in self.input_signs:
# --> 109     conjecture.δ[(i, a)] = _equivalent_in_S(s + a)
#     110 if self.T[(s, "")] == DFA.ACCEPT:
#     111     conjecture.F.add(i)
#
# File ~/Documents/edu/studia2/magisterka/test_algorithm/TTT/../../inferring/InferringDFA.py:97, in InferringDFA._create_automat.<locals>._equivalent_in_S(t)
#      95 t_bitlist = []
#      96 for e in self.E:
# ---> 97     t_bitlist.append(self.T[(t, e)])
#      98 # t_binary = BitVector.BitVector(bitlist=t_bitlist)
#      99 # return binary_rep_of_all_states[str(t_binary)]
#     101 t_binary = t_bitlist
#
# KeyboardInterrupt:

# %%
results.sort(key=lambda x: x.conv)
# Remove degenerated cases (Conv DFA of size 1)
results = [r for r in results if r.conv != 1]

print(f"number of tests: {len(results)}")
# for i, r in enumerate(results):
#     r.print_record()
# Out:
# number of tests: 51

# %%
def create_table(columns, data):
    columns = pd.MultiIndex.from_tuples(columns)
    df = pd.DataFrame(data, columns=columns)

    avg_eq_red = df[(('Reduction', 'EQ'))].mean()
    max_eq_red = df[(('Reduction', 'EQ'))].max()
    min_eq_red = df[(('Reduction', 'EQ'))].min()
    empty_row = pd.DataFrame([[""] * df.shape[1]], columns=df.columns)

    def set_params(row, params):
        for k, v in params:
            row[columns[k]] = v 

    max_red_row = copy.deepcopy(empty_row)
    set_params(row=max_red_row, params=[(0, "Max reduction"), (-1, int(max_eq_red))])
    min_red_row = copy.deepcopy(empty_row)
    set_params(row=min_red_row, params=[(0, "Min reduction"), (-1, int(min_eq_red))])
    avg_red_row = copy.deepcopy(empty_row)
    set_params(row=avg_red_row, params=[(0, "Average reduction"), (-1, int(avg_eq_red))])

    rows = [empty_row, max_red_row, min_red_row, avg_red_row]
    for row in rows:
        df = pd.concat([df, row], ignore_index=True)

    df[('Reduction', 'EQ')] = df[('Reduction', 'EQ')].apply(lambda x: f'{x}%' if isinstance(x, int) else x)
    return df

# %%
ttt_eqs = [r.ttt_eq for r in results]
ttt_wa_eqs = [r.ttt_wa_eq for r in results]
red = ((np.array(ttt_eqs) - np.array(ttt_wa_eqs)) / np.array(ttt_eqs)) * 100

columns = [('Target language', 'conv(DFA1, DFA2)'), ('Target language', 'DFA1'), ('Target language', 'DFA2'), ('TTT', 'EQ'), ('TTT with advice', 'EQ'), ('Reduction', 'EQ')]
data = {
    columns[0]: [r.conv for r in results],
    columns[1]: [r.d1 for r in results],
    columns[2]: [r.d2 for r in results],
    columns[3]: ttt_eqs,
    columns[4]: ttt_wa_eqs,
    columns[5]: [int(r) for r in red]
}

df = create_table(columns=columns, data=data)
display(df)
# Out:
#       Target language             TTT TTT with advice Reduction
#      conv(DFA1, DFA2) DFA1 DFA2    EQ              EQ        EQ
# 0                 462   22   21   451              17       96%
# 1                 475   19   25   464              17       96%
# 2                 480   24   20   465              16       96%
# 3                 506   22   23   490              10       97%
# 4                 506   23   22   493               6       98%
# 5                 513   19   27   508              15       97%
# 6                 522   29   18   517              12       97%
# 7                 551   19   29   535              19       96%
# 8                 558   18   31   543              10       98%
# 9                 572   22   26   548               6       98%
# 10                621   23   27   613               7       98%
# 11                625   25   25   605               9       98%
# 12                627   33   19   602               8       98%
# 13                638   29   22   629               9       98%
# 14                650   25   26   639              18       97%
# 15                675   27   25   662               8       98%
# 16                682   22   31   669               4       99%
# 17                720   36   20   710               9       98%
# 18                720   36   20   712               9       98%
# 19                736   32   23   725              13       98%
# 20                780   26   30   759              23       96%
# 21                783   27   29   758               8       98%
# 22                792   36   22   769              17       97%
# 23                819   21   39   796              24       96%
# 24                836   38   22   816               6       99%
# 25                837   27   31   820              12       98%
# 26                840   30   28   816              10       98%
# 27                841   29   29   820               5       99%
# 28                850   25   34   806               8       99%
# 29                858   33   26   823               2       99%
# 30                875   25   35   849               6       99%
# 31                875   25   35   865              19       97%
# 32                875   25   35   853              18       97%
# 33                888   24   37   870               3       99%
# 34                888   24   37   871              23       97%
# 35                912   24   38   892               5       99%
# 36                925   37   25   888               7       99%
# 37                962   26   37   937               4       99%
# 38                990   30   33   974              12       98%
# 39                992   32   31   984               9       99%
# 40               1050   30   35  1011               8       99%
# 41               1073   29   37  1040              21       97%
# 42               1110   37   30  1103              13       98%
# 43               1221   37   33  1206              23       98%
# 44               1224   34   36  1212              16       98%
# 45               1260   36   35  1187              13       98%
# 46               1295   35   37  1252              14       98%
# 47               1330   35   38  1292               9       99%
# 48               1332   37   36  1270              12       99%
# 49               1404   39   36  1391              16       98%
# 50               1406   37   38  1327               3       99%
# 51
# 52      Max reduction                                       99%
# 53      Min reduction                                       96%
# 54  Average reduction                                       97%
