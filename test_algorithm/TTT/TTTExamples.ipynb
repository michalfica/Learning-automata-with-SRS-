# %%
import copy, sys, pandas as pd
import random
import time
import numpy as np
import subprocess 

sys.path.append("../../")
sys.path.append("../../inferring")
sys.path.append("../../utils/DFA")
from importlib import reload


import inferring.Inferring as Inferring, inferring.InferringDFA as InferringDFA
import utils.automats.DFA
import utils.advice_systems.SRS as SRS

reload(SRS)
reload(Inferring)
reload(InferringDFA)
reload(utils.automats.DFA)

from inferring.Inferring import Inferring
from utils.automats.DFA.DFA import DFA
from utils.advice_systems.SRS import SRS

from inferring.InferringDFA import InferringDFA

# %%
def run_learning_process(target, advice_system=None, check_consistency=False, equiv_query_fashion="BFS", debug=False):
    _dfa = copy.deepcopy(target)
    learn_dfa = InferringDFA(_dfa, 
                                advice_system, 
                                check_consistency=check_consistency, 
                                equiv_query_fashion=equiv_query_fashion,
                                debug=debug)
        
    dfa, cnt, cnt_ex = learn_dfa.run(counterexamples=True)
    return copy.deepcopy(dfa), cnt, len(cnt_ex) +1

# %%
class Record:

    def __init__(self,
                 d1,
                 d2,
                 conv,
                 lstar_with_advice,
                 target=None,
                 ttt_eq=None, 
                 ttt_wa_eq=None):
        self.d1 = d1
        self.d2 = d2
        self.conv = conv
        self.lstar_with_advice = lstar_with_advice
        self.ttt_eq = ttt_eq
        self.ttt_wa_eq = ttt_wa_eq 
        self.target = target

    def print_record(self):
        print(
            f"|d1| = {self.d1}, |d2| = {self.d2}, |conv| = {self.conv}, (mq, eq) = {self.lstar_with_advice}"
        )
    def get_complete_description(self):
        return self.target.print_complete_description()
    
    def print_target(self):
        print(self.target.print_complete_description())

# %%
def getNumberofEQ(s):
    for l in s.splitlines():
        if l.startswith("Learning rounds"):
            return l.split()[-1]

# %%
"""
    Files TTTExample1.java and TTTExample1_withAS.java should be placed in the following directory: examples/src/main/java/de/learnlib/example
    Before executing TTTExample1.java file build learlib project:                                   mvn clean install 
"""


number_of_itreations = 65

#  Fixed random seeds for reproducibility
seeds = [i for i in range(number_of_itreations)]

# The alphabet of the DFA
input_signs = ["a", "b", "c"]

# The bound on the number of states
max_number_of_states = 40

# The list to aggregate the results
results = []

_ = subprocess.run(["cd ../../../learnlib/examples ; mvn clean install; cd ../../magisterka/test_algorithm/TTT"], shell=True, capture_output=True, text=True)
i = 0
while i < number_of_itreations:
    random.seed(seeds[i])
    i += 1
    print(f"iter nr: {i}")

    # Create two random DFAs
    dfa1 = DFA()
    dfa2 = DFA()
    dfa1.create_random_dfa(
        Q=random.randint(max_number_of_states // 2, max_number_of_states),
        input_signs=input_signs,
    )
    dfa2.create_random_dfa(
        Q=random.randint(max_number_of_states // 2, max_number_of_states),
        input_signs=input_signs,
    )

    # Run learning of the language of DFA to minimize dfa1 and dfa2
    d1, _, _ = run_learning_process(target=copy.deepcopy(dfa1))
    d2, _, _ = run_learning_process(target=copy.deepcopy(dfa2))

    if d1.Q < 2 or d2.Q < 2:
        continue
        # Create two random DFAs
        dfa1 = DFA()
        dfa2 = DFA()
        dfa1.create_random_dfa(
            Q=random.randint(max_number_of_states // 2, max_number_of_states),
            input_signs=input_signs,
        )
        dfa2.create_random_dfa(
            Q=random.randint(max_number_of_states // 2, max_number_of_states),
            input_signs=input_signs,
        )

        # Run learning of the language of DFA to minimize dfa1 and dfa2
        d1, _, _ = run_learning_process(target=copy.deepcopy(dfa1))
        d2, _, _ = run_learning_process(target=copy.deepcopy(dfa2))

    # Create a convolution DFA based on d1 and d2
    conv_dfa = DFA()
    conv_dfa.create_convolution(dfa1=d1, dfa2=d2)

    # Learn conv_dfa with advice, and store d - learned automaton 
    start_t = time.time()
    d, lstar_with_advice, lstar_ex_with_advice = run_learning_process(
        target=conv_dfa, advice_system=SRS(), check_consistency=True
    )
    end_t = time.time()

    print("ex time with AS: ", end_t - start_t)
    print(f"|d1.Q| = {d1.Q}, |d2.q| = {d2.Q}, |d.Q| = {d.Q}")
    d.type = DFA.CONV_DFA

    results.append(
        Record(
            d1=d1.Q,
            d2=d2.Q,
            conv=d.Q,
            lstar_with_advice=(lstar_with_advice, lstar_ex_with_advice),
            target=copy.deepcopy(d),
        )
    )
    results[-1].print_record()
    f = open("../../../learnlib/examples/src/main/java/de/learnlib/example/DfaEx" + ".txt", "w")
    f.write(results[-1].get_complete_description())
    f.close()

    ttt_output = subprocess.run(["cd ../../../learnlib/examples ; mvn exec:java -q -Dexec.mainClass=\"de.learnlib.example.TTTExample1\" ; cd ../../magisterka/test_algorithm/TTT"], shell=True, capture_output=True, text=True)
    print("TTT done")
    ttt_wa_output = subprocess.run(["cd ../../../learnlib/examples ; mvn exec:java -q -Dexec.mainClass=\"de.learnlib.example.TTTExample1_withAS\" ; cd ../../magisterka/test_algorithm/TTT"], shell=True, capture_output=True, text=True)
    print("TTT with AS done")

    results[-1].ttt_eq = int(getNumberofEQ(ttt_output.stdout))
    results[-1].ttt_wa_eq = int(getNumberofEQ(ttt_wa_output.stdout))
# Out:
# iter nr: 1
# ex time with AS:  19.26069211959839
# |d1.Q| = 26, |d2.q| = 15, |d.Q| = 390
# |d1| = 26, |d2| = 15, |conv| = 390, (mq, eq) = ([208929, 8], 158)
# TTT done
# -------------------------------------------------------
# 13:52:46.044 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 1104, (1.104 s)
# 13:52:46.047 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 151, (0.151 s)
# Learning rounds [#]: 382
# Queries [#]: 100132
# Symbols [#]: 930329
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 21
# nullQueries [#]: 93337
# Symbols [#]: 1099259
#
# iter nr: 2
# iter nr: 3
# iter nr: 4
# ex time with AS:  3.5688116550445557
# |d1.Q| = 18, |d2.q| = 16, |d.Q| = 288
# |d1| = 18, |d2| = 16, |conv| = 288, (mq, eq) = ([67387, 6], 71)
# TTT done
# -------------------------------------------------------
# 13:52:58.194 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 720, (0.72 s)
# 13:52:58.197 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 126, (0.126 s)
# Learning rounds [#]: 277
# Queries [#]: 45566
# Symbols [#]: 428645
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 15
# nullQueries [#]: 49722
# Symbols [#]: 557419
#
# iter nr: 5
# ex time with AS:  11.396543741226196
# |d1.Q| = 22, |d2.q| = 18, |d.Q| = 396
# |d1| = 22, |d2| = 18, |conv| = 396, (mq, eq) = ([124673, 3], 100)
# TTT done
# -------------------------------------------------------
# 13:53:18.378 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 1405, (1.405 s)
# 13:53:18.381 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 163, (0.163 s)
# Learning rounds [#]: 380
# Queries [#]: 98410
# Symbols [#]: 1127999
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 8
# nullQueries [#]: 72829
# Symbols [#]: 1137917
#
# iter nr: 6
# iter nr: 7
# ex time with AS:  27.851575136184692
# |d1.Q| = 16, |d2.q| = 24, |d.Q| = 384
# |d1| = 16, |d2| = 24, |conv| = 384, (mq, eq) = ([236036, 4], 175)
# TTT done
# -------------------------------------------------------
# 13:53:57.150 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 1598, (1.598 s)
# 13:53:57.155 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 171, (0.171 s)
# Learning rounds [#]: 365
# Queries [#]: 89214
# Symbols [#]: 946230
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 21
# nullQueries [#]: 78381
# Symbols [#]: 923943
#
# iter nr: 8
# iter nr: 9
# ex time with AS:  15.030050277709961
# |d1.Q| = 21, |d2.q| = 21, |d.Q| = 441
# |d1| = 21, |d2| = 21, |conv| = 441, (mq, eq) = ([162664, 2], 105)
# TTT done
# -------------------------------------------------------
# 13:54:24.612 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 1893, (1.893 s)
# 13:54:24.618 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 153, (0.153 s)
# Learning rounds [#]: 433
# Queries [#]: 150690
# Symbols [#]: 1627775
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 15
# nullQueries [#]: 162078
# Symbols [#]: 2090465
#
# iter nr: 10
# ex time with AS:  14.880690336227417
# |d1.Q| = 27, |d2.q| = 17, |d.Q| = 459
# |d1| = 27, |d2| = 17, |conv| = 459, (mq, eq) = ([158363, 6], 105)
# TTT done
# -------------------------------------------------------
# 13:54:51.334 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 942, (0.942 s)
# 13:54:51.338 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 171, (0.171 s)
# Learning rounds [#]: 456
# Queries [#]: 70629
# Symbols [#]: 637562
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 23
# nullQueries [#]: 69280
# Symbols [#]: 791144
#
# iter nr: 11
# ex time with AS:  8.131538152694702
# |d1.Q| = 15, |d2.q| = 24, |d.Q| = 360
# |d1| = 15, |d2| = 24, |conv| = 360, (mq, eq) = ([100733, 2], 77)
# TTT done
# -------------------------------------------------------
# 13:55:10.043 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 974, (0.974 s)
# 13:55:10.046 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 143, (0.143 s)
# Learning rounds [#]: 336
# Queries [#]: 54831
# Symbols [#]: 557153
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 5
# nullQueries [#]: 51225
# Symbols [#]: 876790
#
# iter nr: 12
# ex time with AS:  12.722000122070312
# |d1.Q| = 27, |d2.q| = 17, |d.Q| = 459
# |d1| = 27, |d2| = 17, |conv| = 459, (mq, eq) = ([135814, 3], 92)
# TTT done
# -------------------------------------------------------
# 13:55:33.280 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 830, (0.83 s)
# 13:55:33.284 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 182, (0.182 s)
# Learning rounds [#]: 455
# Queries [#]: 55198
# Symbols [#]: 519827
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 11
# nullQueries [#]: 60620
# Symbols [#]: 802672
#
# iter nr: 13
# ex time with AS:  23.831802368164062
# |d1.Q| = 28, |d2.q| = 26, |d.Q| = 728
# |d1| = 28, |d2| = 26, |conv| = 728, (mq, eq) = ([235253, 2], 96)
# TTT done
# -------------------------------------------------------
# 13:56:09.189 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 2237, (2.237 s)
# 13:56:09.192 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 372, (0.372 s)
# Learning rounds [#]: 713
# Queries [#]: 103829
# Symbols [#]: 1026060
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 6
# nullQueries [#]: 119343
# Symbols [#]: 1817594
#
# iter nr: 14
# ex time with AS:  31.312209844589233
# |d1.Q| = 22, |d2.q| = 25, |d.Q| = 550
# |d1| = 22, |d2| = 25, |conv| = 550, (mq, eq) = ([248439, 7], 146)
# TTT done
# -------------------------------------------------------
# 13:56:53.899 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 2882, (2.882 s)
# 13:56:53.905 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 199, (0.199 s)
# Learning rounds [#]: 524
# Queries [#]: 206218
# Symbols [#]: 2262023
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 9
# nullQueries [#]: 197811
# Symbols [#]: 2984800
#
# iter nr: 15
# iter nr: 16
# ex time with AS:  5.335008144378662
# |d1.Q| = 21, |d2.q| = 15, |d.Q| = 315
# |d1| = 21, |d2| = 15, |conv| = 315, (mq, eq) = ([78475, 6], 70)
# TTT done
# -------------------------------------------------------
# 13:57:12.538 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 787, (0.787 s)
# 13:57:12.541 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 155, (0.155 s)
# Learning rounds [#]: 305
# Queries [#]: 39888
# Symbols [#]: 370372
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 13
# nullQueries [#]: 40790
# Symbols [#]: 485545
#
# iter nr: 17
# ex time with AS:  3.874521017074585
# |d1.Q| = 21, |d2.q| = 13, |d.Q| = 273
# |d1| = 21, |d2| = 13, |conv| = 273, (mq, eq) = ([60600, 2], 64)
# TTT done
# -------------------------------------------------------
# 13:57:26.604 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 921, (0.921 s)
# 13:57:26.610 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 130, (0.13 s)
# Learning rounds [#]: 268
# Queries [#]: 48766
# Symbols [#]: 491331
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 16
# nullQueries [#]: 40429
# Symbols [#]: 523710
#
# iter nr: 18
# ex time with AS:  14.895336866378784
# |d1.Q| = 27, |d2.q| = 19, |d.Q| = 513
# |d1| = 27, |d2| = 19, |conv| = 513, (mq, eq) = ([174867, 1], 95)
# TTT done
# -------------------------------------------------------
# 13:57:51.934 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 1404, (1.404 s)
# 13:57:51.937 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 197, (0.197 s)
# Learning rounds [#]: 503
# Queries [#]: 107846
# Symbols [#]: 1109944
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 8
# nullQueries [#]: 119449
# Symbols [#]: 1776767
#
# iter nr: 19
# iter nr: 20
# ex time with AS:  5.091918706893921
# |d1.Q| = 13, |d2.q| = 20, |d.Q| = 260
# |d1| = 13, |d2| = 20, |conv| = 260, (mq, eq) = ([70103, 3], 76)
# TTT done
# -------------------------------------------------------
# 13:58:07.475 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 669, (0.669 s)
# 13:58:07.480 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 140, (0.14 s)
# Learning rounds [#]: 248
# Queries [#]: 30869
# Symbols [#]: 284533
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 15
# nullQueries [#]: 29137
# Symbols [#]: 342603
#
# iter nr: 21
# ex time with AS:  8.941895723342896
# |d1.Q| = 18, |d2.q| = 27, |d.Q| = 486
# |d1| = 18, |d2| = 27, |conv| = 486, (mq, eq) = ([123829, 1], 71)
# TTT done
# -------------------------------------------------------
# 13:58:25.936 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 842, (0.842 s)
# 13:58:25.940 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 197, (0.197 s)
# Learning rounds [#]: 480
# Queries [#]: 49271
# Symbols [#]: 435916
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 17
# nullQueries [#]: 47291
# Symbols [#]: 656490
#
# iter nr: 22
# ex time with AS:  16.718586444854736
# |d1.Q| = 19, |d2.q| = 20, |d.Q| = 380
# |d1| = 19, |d2| = 20, |conv| = 380, (mq, eq) = ([150339, 4], 119)
# TTT done
# -------------------------------------------------------
# 13:58:53.191 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 923, (0.923 s)
# 13:58:53.195 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 152, (0.152 s)
# Learning rounds [#]: 369
# Queries [#]: 65752
# Symbols [#]: 653716
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 9
# nullQueries [#]: 54746
# Symbols [#]: 863534
#
# iter nr: 23
# ex time with AS:  8.328181982040405
# |d1.Q| = 17, |d2.q| = 25, |d.Q| = 425
# |d1| = 17, |d2| = 25, |conv| = 425, (mq, eq) = ([105677, 2], 71)
# TTT done
# -------------------------------------------------------
# 13:59:10.731 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 1132, (1.132 s)
# 13:59:10.736 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 185, (0.185 s)
# Learning rounds [#]: 415
# Queries [#]: 70717
# Symbols [#]: 695832
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 25
# nullQueries [#]: 65576
# Symbols [#]: 770814
#
# iter nr: 24
# ex time with AS:  27.974600791931152
# |d1.Q| = 24, |d2.q| = 21, |d.Q| = 504
# |d1| = 24, |d2| = 21, |conv| = 504, (mq, eq) = ([251304, 3], 155)
# TTT done
# -------------------------------------------------------
# 13:59:48.512 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 1996, (1.996 s)
# 13:59:48.515 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 165, (0.165 s)
# Learning rounds [#]: 460
# Queries [#]: 139523
# Symbols [#]: 1557816
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 13
# nullQueries [#]: 132285
# Symbols [#]: 1844714
#
# iter nr: 25
# iter nr: 26
# ex time with AS:  23.048757314682007
# |d1.Q| = 26, |d2.q| = 27, |d.Q| = 702
# |d1| = 26, |d2| = 27, |conv| = 702, (mq, eq) = ([239338, 2], 99)
# TTT done
# -------------------------------------------------------
# 14:00:23.268 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 2393, (2.393 s)
# 14:00:23.273 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 305, (0.305 s)
# Learning rounds [#]: 689
# Queries [#]: 129588
# Symbols [#]: 1345237
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 14
# nullQueries [#]: 140695
# Symbols [#]: 2001578
#
# iter nr: 27
# ex time with AS:  12.122046709060669
# |d1.Q| = 20, |d2.q| = 27, |d.Q| = 540
# |d1| = 20, |d2| = 27, |conv| = 540, (mq, eq) = ([148384, 4], 82)
# TTT done
# -------------------------------------------------------
# 14:00:47.821 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 1358, (1.358 s)
# 14:00:47.824 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 232, (0.232 s)
# Learning rounds [#]: 523
# Queries [#]: 66065
# Symbols [#]: 744170
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 4
# nullQueries [#]: 58770
# Symbols [#]: 1221262
#
# iter nr: 28
# ex time with AS:  25.59900140762329
# |d1.Q| = 30, |d2.q| = 22, |d.Q| = 660
# |d1| = 30, |d2| = 22, |conv| = 660, (mq, eq) = ([259687, 6], 122)
# TTT done
# -------------------------------------------------------
# 14:01:25.269 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 1757, (1.757 s)
# 14:01:25.272 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 256, (0.256 s)
# Learning rounds [#]: 636
# Queries [#]: 140714
# Symbols [#]: 1366038
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 11
# nullQueries [#]: 130992
# Symbols [#]: 1883693
#
# iter nr: 29
# ex time with AS:  19.125351905822754
# |d1.Q| = 17, |d2.q| = 28, |d.Q| = 476
# |d1| = 17, |d2| = 28, |conv| = 476, (mq, eq) = ([205546, 3], 119)
# TTT done
# -------------------------------------------------------
# 14:01:55.118 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 1205, (1.205 s)
# 14:01:55.121 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 159, (0.159 s)
# Learning rounds [#]: 466
# Queries [#]: 99043
# Symbols [#]: 1086333
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 12
# nullQueries [#]: 101518
# Symbols [#]: 1715602
#
# iter nr: 30
# iter nr: 31
# ex time with AS:  38.64720416069031
# |d1.Q| = 24, |d2.q| = 30, |d.Q| = 720
# |d1| = 24, |d2| = 30, |conv| = 720, (mq, eq) = ([385614, 13], 152)
# TTT done
# -------------------------------------------------------
# 14:02:47.626 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 4991, (4.991 s)
# 14:02:47.630 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 264, (0.264 s)
# Learning rounds [#]: 704
# Queries [#]: 354074
# Symbols [#]: 4521321
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 22
# nullQueries [#]: 209644
# Symbols [#]: 3633458
#
# iter nr: 32
# ex time with AS:  7.598077297210693
# |d1.Q| = 12, |d2.q| = 25, |d.Q| = 300
# |d1| = 12, |d2| = 25, |conv| = 300, (mq, eq) = ([106818, 10], 109)
# TTT done
# -------------------------------------------------------
# 14:03:08.499 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 440, (0.44 s)
# 14:03:08.503 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 88, (0.088 s)
# Learning rounds [#]: 293
# Queries [#]: 45151
# Symbols [#]: 402837
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 14
# nullQueries [#]: 22998
# Symbols [#]: 279975
#
# iter nr: 33
# iter nr: 34
# ex time with AS:  7.888001203536987
# |d1.Q| = 19, |d2.q| = 19, |d.Q| = 361
# |d1| = 19, |d2| = 19, |conv| = 361, (mq, eq) = ([109916, 4], 93)
# TTT done
# -------------------------------------------------------
# 14:03:24.536 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 930, (0.93 s)
# 14:03:24.541 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 193, (0.193 s)
# Learning rounds [#]: 352
# Queries [#]: 48912
# Symbols [#]: 449668
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 15
# nullQueries [#]: 48826
# Symbols [#]: 540603
#
# iter nr: 35
# iter nr: 36
# ex time with AS:  11.396071672439575
# |d1.Q| = 24, |d2.q| = 25, |d.Q| = 600
# |d1| = 24, |d2| = 25, |conv| = 600, (mq, eq) = ([165902, 1], 78)
# TTT done
# -------------------------------------------------------
# 14:03:44.476 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 1395, (1.395 s)
# 14:03:44.479 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 193, (0.193 s)
# Learning rounds [#]: 570
# Queries [#]: 113399
# Symbols [#]: 1092991
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 16
# nullQueries [#]: 78938
# Symbols [#]: 958521
#
# iter nr: 37
# ex time with AS:  13.857371091842651
# |d1.Q| = 24, |d2.q| = 16, |d.Q| = 384
# |d1| = 24, |d2| = 16, |conv| = 384, (mq, eq) = ([157683, 3], 120)
# TTT done
# -------------------------------------------------------
# 14:04:08.099 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 1016, (1.016 s)
# 14:04:08.101 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 168, (0.168 s)
# Learning rounds [#]: 375
# Queries [#]: 86998
# Symbols [#]: 866943
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 14
# nullQueries [#]: 88381
# Symbols [#]: 1145730
#
# iter nr: 38
# ex time with AS:  2.8456201553344727
# |d1.Q| = 17, |d2.q| = 15, |d.Q| = 255
# |d1| = 17, |d2| = 15, |conv| = 255, (mq, eq) = ([62108, 3], 70)
# TTT done
# -------------------------------------------------------
# 14:04:18.914 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 766, (0.766 s)
# 14:04:18.919 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 116, (0.116 s)
# Learning rounds [#]: 249
# Queries [#]: 48925
# Symbols [#]: 426179
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 8
# nullQueries [#]: 43043
# Symbols [#]: 427007
#
# iter nr: 39
# ex time with AS:  25.094805240631104
# |d1.Q| = 25, |d2.q| = 21, |d.Q| = 525
# |d1| = 25, |d2| = 21, |conv| = 525, (mq, eq) = ([245920, 2], 141)
# TTT done
# -------------------------------------------------------
# 14:04:51.776 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 1518, (1.518 s)
# 14:04:51.781 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 196, (0.196 s)
# Learning rounds [#]: 519
# Queries [#]: 137069
# Symbols [#]: 1343243
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 16
# nullQueries [#]: 123929
# Symbols [#]: 1606943
#
# iter nr: 40
# ex time with AS:  28.6404812335968
# |d1.Q| = 20, |d2.q| = 27, |d.Q| = 540
# |d1| = 20, |d2| = 27, |conv| = 540, (mq, eq) = ([266804, 4], 143)
# TTT done
# -------------------------------------------------------
# 14:05:29.991 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 1715, (1.715 s)
# 14:05:29.994 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 182, (0.182 s)
# Learning rounds [#]: 527
# Queries [#]: 122246
# Symbols [#]: 1322185
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 3
# nullQueries [#]: 167557
# Symbols [#]: 3212835
#
# iter nr: 41
# iter nr: 42
# ex time with AS:  34.8239963054657
# |d1.Q| = 26, |d2.q| = 27, |d.Q| = 702
# |d1| = 26, |d2| = 27, |conv| = 702, (mq, eq) = ([317046, 2], 137)
# TTT done
# -------------------------------------------------------
# 14:06:19.679 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 4387, (4.387 s)
# 14:06:19.683 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 222, (0.222 s)
# Learning rounds [#]: 688
# Queries [#]: 370374
# Symbols [#]: 3993342
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 10
# nullQueries [#]: 294023
# Symbols [#]: 4558536
#
# iter nr: 43
# ex time with AS:  14.221666812896729
# |d1.Q| = 17, |d2.q| = 25, |d.Q| = 425
# |d1| = 17, |d2| = 25, |conv| = 425, (mq, eq) = ([175475, 2], 113)
# TTT done
# -------------------------------------------------------
# 14:06:47.373 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 2167, (2.167 s)
# 14:06:47.375 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 97, (0.097 s)
# Learning rounds [#]: 405
# Queries [#]: 185622
# Symbols [#]: 2662297
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 7
# nullQueries [#]: 134687
# Symbols [#]: 2589309
#
# iter nr: 44
# ex time with AS:  7.041576385498047
# |d1.Q| = 14, |d2.q| = 19, |d.Q| = 266
# |d1| = 14, |d2| = 19, |conv| = 266, (mq, eq) = ([91864, 7], 110)
# TTT done
# -------------------------------------------------------
# 14:07:09.150 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 821, (0.821 s)
# 14:07:09.153 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 75, (0.075 s)
# Learning rounds [#]: 259
# Queries [#]: 71731
# Symbols [#]: 746543
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 14
# nullQueries [#]: 67251
# Symbols [#]: 794217
#
# iter nr: 45
# ex time with AS:  16.540221452713013
# |d1.Q| = 28, |d2.q| = 15, |d.Q| = 420
# |d1| = 28, |d2| = 15, |conv| = 420, (mq, eq) = ([176736, 4], 120)
# TTT done
# -------------------------------------------------------
# 14:07:34.224 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 1188, (1.188 s)
# 14:07:34.228 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 128, (0.128 s)
# Learning rounds [#]: 405
# Queries [#]: 93687
# Symbols [#]: 1052367
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 6
# nullQueries [#]: 77288
# Symbols [#]: 1289871
#
# iter nr: 46
# ex time with AS:  12.941715002059937
# |d1.Q| = 20, |d2.q| = 27, |d.Q| = 540
# |d1| = 20, |d2| = 27, |conv| = 540, (mq, eq) = ([174776, 2], 94)
# TTT done
# -------------------------------------------------------
# 14:07:56.759 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 1039, (1.039 s)
# 14:07:56.762 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 142, (0.142 s)
# Learning rounds [#]: 526
# Queries [#]: 87570
# Symbols [#]: 789796
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 7
# nullQueries [#]: 88691
# Symbols [#]: 1033184
#
# iter nr: 47
# ex time with AS:  4.36225152015686
# |d1.Q| = 17, |d2.q| = 16, |d.Q| = 272
# |d1| = 17, |d2| = 16, |conv| = 272, (mq, eq) = ([77572, 5], 86)
# TTT done
# -------------------------------------------------------
# 14:08:09.386 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 549, (0.549 s)
# 14:08:09.390 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 115, (0.115 s)
# Learning rounds [#]: 268
# Queries [#]: 41357
# Symbols [#]: 364583
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 14
# nullQueries [#]: 44715
# Symbols [#]: 469402
#
# iter nr: 48
# ex time with AS:  9.669806957244873
# |d1.Q| = 24, |d2.q| = 16, |d.Q| = 384
# |d1| = 24, |d2| = 16, |conv| = 384, (mq, eq) = ([136261, 3], 100)
# TTT done
# -------------------------------------------------------
# 14:08:26.970 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 1074, (1.074 s)
# 14:08:26.973 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 116, (0.116 s)
# Learning rounds [#]: 377
# Queries [#]: 86106
# Symbols [#]: 895582
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 10
# nullQueries [#]: 71703
# Symbols [#]: 1143966
#
# iter nr: 49
# ex time with AS:  25.797548055648804
# |d1.Q| = 21, |d2.q| = 28, |d.Q| = 588
# |d1| = 21, |d2| = 28, |conv| = 588, (mq, eq) = ([260596, 2], 129)
# TTT done
# -------------------------------------------------------
# 14:09:05.378 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 3355, (3.355 s)
# 14:09:05.381 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 272, (0.272 s)
# Learning rounds [#]: 577
# Queries [#]: 224926
# Symbols [#]: 2394863
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 9
# nullQueries [#]: 196143
# Symbols [#]: 3358767
#
# iter nr: 50
# ex time with AS:  7.508881330490112
# |d1.Q| = 16, |d2.q| = 20, |d.Q| = 320
# |d1| = 16, |d2| = 20, |conv| = 320, (mq, eq) = ([102354, 4], 98)
# TTT done
# -------------------------------------------------------
# 14:09:25.333 INFO     d.l.u.s.SimpleProfiler - Learning [ms]: 799, (0.799 s)
# 14:09:25.336 INFO     d.l.u.s.SimpleProfiler - Searching for counterexample [ms]: 121, (0.121 s)
# Learning rounds [#]: 313
# Queries [#]: 76074
# Symbols [#]: 684743
# -------------------------------------------------------
#
# TTT with AS done
# Learning rounds: 20
# nullQueries [#]: 82664
# Symbols [#]: 1012898

# %%
results.sort(key=lambda x: x.conv)
# Remove degenerated cases (Conv DFA of size 1)
results = [r for r in results if r.conv != 1]

print(f"number of tests: {len(results)}")
for i, r in enumerate(results):
    r.print_record()
    f = open("../../../learnlib/examples/src/main/java/de/learnlib/example/DfaEx" + str(i) + ".txt", "w")
    f.write(results[i].get_complete_description())
    f.close()
# Out:
# number of tests: 39
# |d1| = 17, |d2| = 15, |conv| = 255, (mq, eq) = ([62108, 3], 70)
# |d1| = 13, |d2| = 20, |conv| = 260, (mq, eq) = ([70103, 3], 76)
# |d1| = 14, |d2| = 19, |conv| = 266, (mq, eq) = ([91864, 7], 110)
# |d1| = 17, |d2| = 16, |conv| = 272, (mq, eq) = ([77572, 5], 86)
# |d1| = 21, |d2| = 13, |conv| = 273, (mq, eq) = ([60600, 2], 64)
# |d1| = 18, |d2| = 16, |conv| = 288, (mq, eq) = ([67387, 6], 71)
# |d1| = 12, |d2| = 25, |conv| = 300, (mq, eq) = ([106818, 10], 109)
# |d1| = 21, |d2| = 15, |conv| = 315, (mq, eq) = ([78475, 6], 70)
# |d1| = 16, |d2| = 20, |conv| = 320, (mq, eq) = ([102354, 4], 98)
# |d1| = 15, |d2| = 24, |conv| = 360, (mq, eq) = ([100733, 2], 77)
# |d1| = 19, |d2| = 19, |conv| = 361, (mq, eq) = ([109916, 4], 93)
# |d1| = 19, |d2| = 20, |conv| = 380, (mq, eq) = ([150339, 4], 119)
# |d1| = 16, |d2| = 24, |conv| = 384, (mq, eq) = ([236036, 4], 175)
# |d1| = 24, |d2| = 16, |conv| = 384, (mq, eq) = ([157683, 3], 120)
# |d1| = 24, |d2| = 16, |conv| = 384, (mq, eq) = ([136261, 3], 100)
# |d1| = 26, |d2| = 15, |conv| = 390, (mq, eq) = ([208929, 8], 158)
# |d1| = 22, |d2| = 18, |conv| = 396, (mq, eq) = ([124673, 3], 100)
# |d1| = 28, |d2| = 15, |conv| = 420, (mq, eq) = ([176736, 4], 120)
# |d1| = 17, |d2| = 25, |conv| = 425, (mq, eq) = ([105677, 2], 71)
# |d1| = 17, |d2| = 25, |conv| = 425, (mq, eq) = ([175475, 2], 113)
# |d1| = 21, |d2| = 21, |conv| = 441, (mq, eq) = ([162664, 2], 105)
# |d1| = 27, |d2| = 17, |conv| = 459, (mq, eq) = ([158363, 6], 105)
# |d1| = 27, |d2| = 17, |conv| = 459, (mq, eq) = ([135814, 3], 92)
# |d1| = 17, |d2| = 28, |conv| = 476, (mq, eq) = ([205546, 3], 119)
# |d1| = 18, |d2| = 27, |conv| = 486, (mq, eq) = ([123829, 1], 71)
# |d1| = 24, |d2| = 21, |conv| = 504, (mq, eq) = ([251304, 3], 155)
# |d1| = 27, |d2| = 19, |conv| = 513, (mq, eq) = ([174867, 1], 95)
# |d1| = 25, |d2| = 21, |conv| = 525, (mq, eq) = ([245920, 2], 141)
# |d1| = 20, |d2| = 27, |conv| = 540, (mq, eq) = ([148384, 4], 82)
# |d1| = 20, |d2| = 27, |conv| = 540, (mq, eq) = ([266804, 4], 143)
# |d1| = 20, |d2| = 27, |conv| = 540, (mq, eq) = ([174776, 2], 94)
# |d1| = 22, |d2| = 25, |conv| = 550, (mq, eq) = ([248439, 7], 146)
# |d1| = 21, |d2| = 28, |conv| = 588, (mq, eq) = ([260596, 2], 129)
# |d1| = 24, |d2| = 25, |conv| = 600, (mq, eq) = ([165902, 1], 78)
# |d1| = 30, |d2| = 22, |conv| = 660, (mq, eq) = ([259687, 6], 122)
# |d1| = 26, |d2| = 27, |conv| = 702, (mq, eq) = ([239338, 2], 99)
# |d1| = 26, |d2| = 27, |conv| = 702, (mq, eq) = ([317046, 2], 137)
# |d1| = 24, |d2| = 30, |conv| = 720, (mq, eq) = ([385614, 13], 152)
# |d1| = 28, |d2| = 26, |conv| = 728, (mq, eq) = ([235253, 2], 96)

# %%
def create_table(columns, data):
    columns = pd.MultiIndex.from_tuples(columns)
    df = pd.DataFrame(data, columns=columns)

    avg_eq_red = df[(('Reduction', 'EQ'))].mean()
    max_eq_red = df[(('Reduction', 'EQ'))].max()
    min_eq_red = df[(('Reduction', 'EQ'))].min()
    empty_row = pd.DataFrame([[""] * df.shape[1]], columns=df.columns)

    def set_params(row, params):
        for k, v in params:
            row[columns[k]] = v 

    max_red_row = copy.deepcopy(empty_row)
    set_params(row=max_red_row, params=[(0, "Max reduction"), (-1, int(max_eq_red))])
    min_red_row = copy.deepcopy(empty_row)
    set_params(row=min_red_row, params=[(0, "Min reduction"), (-1, int(min_eq_red))])
    avg_red_row = copy.deepcopy(empty_row)
    set_params(row=avg_red_row, params=[(0, "Average reduction"), (-1, int(avg_eq_red))])

    rows = [empty_row, max_red_row, min_red_row, avg_red_row]
    for row in rows:
        df = pd.concat([df, row], ignore_index=True)

    df[('Reduction', 'EQ')] = df[('Reduction', 'EQ')].apply(lambda x: f'{x}%' if isinstance(x, int) else x)
    return df

# %%
ttt_eqs = [r.ttt_eq for r in results]
ttt_wa_eqs = [r.ttt_wa_eq for r in results]
red = ((np.array(ttt_eqs) - np.array(ttt_wa_eqs)) / np.array(ttt_eqs)) * 100

columns = [('Target language', 'conv(DFA1, DFA2)'), ('Target language', 'DFA1'), ('Target language', 'DFA2'), ('TTT', 'EQ'), ('TTT with advice', 'EQ'), ('Reduction', 'EQ')]
data = {
    columns[0]: [r.conv for r in results],
    columns[1]: [r.d1 for r in results],
    columns[2]: [r.d2 for r in results],
    columns[3]: ttt_eqs,
    columns[4]: ttt_wa_eqs,
    columns[5]: [int(r) for r in red]
}

df = create_table(columns=columns, data=data)
display(df)
# Out:
#       Target language            TTT TTT with advice Reduction
#      conv(DFA1, DFA2) DFA1 DFA2   EQ              EQ        EQ
# 0                 255   17   15  249               8       96%
# 1                 260   13   20  248              15       93%
# 2                 266   14   19  259              14       94%
# 3                 272   17   16  268              14       94%
# 4                 273   21   13  268              16       94%
# 5                 288   18   16  277              15       94%
# 6                 300   12   25  293              14       95%
# 7                 315   21   15  305              13       95%
# 8                 320   16   20  313              20       93%
# 9                 360   15   24  336               5       98%
# 10                361   19   19  352              15       95%
# 11                380   19   20  369               9       97%
# 12                384   16   24  365              21       94%
# 13                384   24   16  375              14       96%
# 14                384   24   16  377              10       97%
# 15                390   26   15  382              21       94%
# 16                396   22   18  380               8       97%
# 17                420   28   15  405               6       98%
# 18                425   17   25  415              25       93%
# 19                425   17   25  405               7       98%
# 20                441   21   21  433              15       96%
# 21                459   27   17  456              23       94%
# 22                459   27   17  455              11       97%
# 23                476   17   28  466              12       97%
# 24                486   18   27  480              17       96%
# 25                504   24   21  460              13       97%
# 26                513   27   19  503               8       98%
# 27                525   25   21  519              16       96%
# 28                540   20   27  523               4       99%
# 29                540   20   27  527               3       99%
# 30                540   20   27  526               7       98%
# 31                550   22   25  524               9       98%
# 32                588   21   28  577               9       98%
# 33                600   24   25  570              16       97%
# 34                660   30   22  636              11       98%
# 35                702   26   27  689              14       97%
# 36                702   26   27  688              10       98%
# 37                720   24   30  704              22       96%
# 38                728   28   26  713               6       99%
# 39
# 40      Max reduction                                      99%
# 41      Min reduction                                      93%
# 42  Average reduction                                      96%
