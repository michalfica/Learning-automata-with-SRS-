# %% [markdown]
# ## Przykłady wykrywania wzorców - badanie dlaczego stopniowe uczenie jest lepsze

# %%
from importlib import reload
import copy
import sys

sys.path.append("../")

# %%
import utils.InferringMM, utils.OracleDFA, utils.Mealymachine, PatternDetection.PatterndetectionMM 

reload(utils.InferringMM)
reload(utils.OracleDFA)
reload(utils.Mealymachine)
reload(PatternDetection.PatterndetectionMM)

from utils.InferringMM import *
from utils.OracleDFA import OracleDFA
from PatternDetection.PatterndetectionMM import PatternMM

# %%
def run_learning_process(_mm, oracle=None, debug=False):
    learn_mm = InferringMM(_mm, oracle, debug=debug)
    mm, cnt, cnt_ex = learn_mm.run(counterexamples=True)
    print(f"kontrprzykłady: {cnt_ex}, cnt = {cnt}")
    return copy.deepcopy(mm)


def find_minm_mm(_mm, debug=False):
    learn_mm = InferringMM(_mm, debug=debug)
    mm, _, _ = learn_mm.run(counterexamples=True)
    return copy.deepcopy(mm)

# %% [markdown]
# ### Pierwszy przykład

# %%
in_a, out_a = ["a", "b", "c"], ["0", "1"]

mm_1 = PatternMM(["abc"], in_a, out_a)
mm_1 = run_learning_process(copy.deepcopy(mm_1), debug=True)
mm_1.print_states()
# Out:
# S = [''], rozmiar E = ['a', 'b', 'c']
# zamkniętość sprawdzona - S = [''], rozmiar E = ['a', 'b', 'c']
# hipoteza:
# (0,a) --> '0',0
# (0,b) --> '0',0
# (0,c) --> '0',0
# kontrprzyklad = abc
# S = [''], rozmiar E = ['a', 'b', 'bc', 'c']
# zamkniętość sprawdzona - S = ['', 'a', 'ab'], rozmiar E = ['a', 'b', 'bc', 'c']
# hipoteza:
# (0,a) --> '0',1
# (0,b) --> '0',0
# (0,c) --> '0',0
# (1,a) --> '0',1
# (1,b) --> '0',2
# (1,c) --> '0',0
# (2,a) --> '0',1
# (2,b) --> '0',0
# (2,c) --> '1',0
# kontrprzykłady: [3], cnt = [37, 2]
# # stanów = 3

# %%
mm_2 = PatternMM(["abc", "baca"], in_a, out_a)
mm_2 = run_learning_process(copy.deepcopy(mm_2), oracle=mm_1, debug=True)
mm_2.print_states()
# Out:
# S = [''], rozmiar E = ['a', 'b', 'c']
# zamkniętość sprawdzona - S = [''], rozmiar E = ['a', 'b', 'c']
# hipoteza:
# (0,a) --> '0',0
# (0,b) --> '0',0
# (0,c) --> '0',0
# kontrprzyklad = abc
# S = [''], rozmiar E = ['a', 'b', 'bc', 'c']
# zamkniętość sprawdzona - S = ['', 'a', 'ab'], rozmiar E = ['a', 'b', 'bc', 'c']
# hipoteza:
# (0,a) --> '0',1
# (0,b) --> '0',0
# (0,c) --> '0',0
# (1,a) --> '0',1
# (1,b) --> '0',2
# (1,c) --> '0',0
# (2,a) --> '0',1
# (2,b) --> '0',0
# (2,c) --> '1',0
# kontrprzyklad = baca
# zapytanie o słowo baca
# zapytanie o słowo abaca
# zapytanie o słowo abbaca
# S = ['', 'a', 'ab'], rozmiar E = ['a', 'aca', 'b', 'bc', 'c', 'ca']
# zapytanie o słowo bbaca
# zapytanie o słowo babaca
# zapytanie o słowo bacaca
# zapytanie o słowo bacaaca
# zapytanie o słowo bacac
# zapytanie o słowo bacaa
# zapytanie o słowo bacabc
# zapytanie o słowo bacab
# zapytanie o słowo bacbaca
# zamkniętość sprawdzona - S = ['', 'a', 'ab', 'b', 'ba', 'bac'], rozmiar E = ['a', 'aca', 'b', 'bc', 'c', 'ca']
# hipoteza:
# (0,a) --> '0',2
# (0,b) --> '0',5
# (0,c) --> '0',0
# (1,a) --> '0',4
# (1,b) --> '0',5
# (1,c) --> '1',0
# (2,a) --> '0',2
# (2,b) --> '0',1
# (2,c) --> '0',0
# (3,a) --> '1',2
# (3,b) --> '0',5
# (3,c) --> '0',0
# (4,a) --> '0',2
# (4,b) --> '0',1
# (4,c) --> '0',3
# (5,a) --> '0',4
# (5,b) --> '0',5
# (5,c) --> '0',0
# kontrprzykłady: [3, 4], cnt = [12, 3]
# # stanów = 6

# %%
mm_3 = PatternMM(["abc", "baca", "cacab"], in_a, out_a)
mm_3 = run_learning_process(copy.deepcopy(mm_3), oracle=None, debug=True)
mm_3.print_states()
# Out:
# S = [''], rozmiar E = ['a', 'b', 'c']
# zamkniętość sprawdzona - S = [''], rozmiar E = ['a', 'b', 'c']
# hipoteza:
# (0,a) --> '0',0
# (0,b) --> '0',0
# (0,c) --> '0',0
# kontrprzyklad = abc
# S = [''], rozmiar E = ['a', 'b', 'bc', 'c']
# zamkniętość sprawdzona - S = ['', 'a', 'ab'], rozmiar E = ['a', 'b', 'bc', 'c']
# hipoteza:
# (0,a) --> '0',1
# (0,b) --> '0',0
# (0,c) --> '0',0
# (1,a) --> '0',1
# (1,b) --> '0',2
# (1,c) --> '0',0
# (2,a) --> '0',1
# (2,b) --> '0',0
# (2,c) --> '1',0
# kontrprzyklad = baca
# S = ['', 'a', 'ab'], rozmiar E = ['a', 'aca', 'b', 'bc', 'c', 'ca']
# zamkniętość sprawdzona - S = ['', 'a', 'ab', 'b', 'ba', 'bac'], rozmiar E = ['a', 'aca', 'b', 'bc', 'c', 'ca']
# hipoteza:
# (0,a) --> '0',2
# (0,b) --> '0',5
# (0,c) --> '0',0
# (1,a) --> '0',4
# (1,b) --> '0',5
# (1,c) --> '1',0
# (2,a) --> '0',2
# (2,b) --> '0',1
# (2,c) --> '0',0
# (3,a) --> '1',2
# (3,b) --> '0',5
# (3,c) --> '0',0
# (4,a) --> '0',2
# (4,b) --> '0',1
# (4,c) --> '0',3
# (5,a) --> '0',4
# (5,b) --> '0',5
# (5,c) --> '0',0
# kontrprzyklad = cacab
# S = ['', 'a', 'ab', 'b', 'ba', 'bac'], rozmiar E = ['a', 'ab', 'aca', 'acab', 'b', 'bc', 'c', 'ca', 'cab']
# zamkniętość sprawdzona - S = ['', 'a', 'ab', 'b', 'ba', 'bac', 'c', 'ca', 'cac', 'caca'], rozmiar E = ['a', 'ab', 'aca', 'acab', 'b', 'bc', 'c', 'ca', 'cab']
# hipoteza:
# (0,a) --> '0',3
# (0,b) --> '0',9
# (0,c) --> '0',2
# (1,a) --> '0',7
# (1,b) --> '0',9
# (1,c) --> '1',2
# (2,a) --> '0',5
# (2,b) --> '0',9
# (2,c) --> '0',2
# (3,a) --> '0',3
# (3,b) --> '0',1
# (3,c) --> '0',2
# (4,a) --> '0',3
# (4,b) --> '1',1
# (4,c) --> '0',8
# (5,a) --> '0',3
# (5,b) --> '0',1
# (5,c) --> '0',8
# (6,a) --> '1',5
# (6,b) --> '0',9
# (6,c) --> '0',2
# (7,a) --> '0',3
# (7,b) --> '0',1
# (7,c) --> '0',6
# (8,a) --> '0',4
# (8,b) --> '0',9
# (8,c) --> '0',2
# (9,a) --> '0',7
# (9,b) --> '0',9
# (9,c) --> '0',2
# kontrprzykłady: [3, 4, 5], cnt = [219, 4]
# # stanów = 10

# %%
mm_4 = PatternMM(["abc", "baca", "cacab", "acccb"], in_a, out_a)
mm_4 = run_learning_process(copy.deepcopy(mm_4), oracle=mm_3, debug=True)
mm_4.print_states()
# Out:
# S = [''], rozmiar E = ['a', 'b', 'c']
# zamkniętość sprawdzona - S = [''], rozmiar E = ['a', 'b', 'c']
# hipoteza:
# (0,a) --> '0',0
# (0,b) --> '0',0
# (0,c) --> '0',0
# kontrprzyklad = abc
# S = [''], rozmiar E = ['a', 'b', 'bc', 'c']
# zamkniętość sprawdzona - S = ['', 'a', 'ab'], rozmiar E = ['a', 'b', 'bc', 'c']
# hipoteza:
# (0,a) --> '0',1
# (0,b) --> '0',0
# (0,c) --> '0',0
# (1,a) --> '0',1
# (1,b) --> '0',2
# (1,c) --> '0',0
# (2,a) --> '0',1
# (2,b) --> '0',0
# (2,c) --> '1',0
# kontrprzyklad = baca
# S = ['', 'a', 'ab'], rozmiar E = ['a', 'aca', 'b', 'bc', 'c', 'ca']
# zamkniętość sprawdzona - S = ['', 'a', 'ab', 'b', 'ba', 'bac'], rozmiar E = ['a', 'aca', 'b', 'bc', 'c', 'ca']
# hipoteza:
# (0,a) --> '0',2
# (0,b) --> '0',5
# (0,c) --> '0',0
# (1,a) --> '0',4
# (1,b) --> '0',5
# (1,c) --> '1',0
# (2,a) --> '0',2
# (2,b) --> '0',1
# (2,c) --> '0',0
# (3,a) --> '1',2
# (3,b) --> '0',5
# (3,c) --> '0',0
# (4,a) --> '0',2
# (4,b) --> '0',1
# (4,c) --> '0',3
# (5,a) --> '0',4
# (5,b) --> '0',5
# (5,c) --> '0',0
# kontrprzyklad = acccb
# zapytanie o słowo acccb
# zapytanie o słowo bacccb
# S = ['', 'a', 'ab', 'b', 'ba', 'bac'], rozmiar E = ['a', 'aca', 'b', 'bc', 'c', 'ca', 'cb', 'ccb']
# zapytanie o słowo acccbc
# zapytanie o słowo acccbaca
# zapytanie o słowo acccba
# zapytanie o słowo acccbcb
# zapytanie o słowo acccbccb
# zapytanie o słowo acccbca
# zapytanie o słowo acccbbc
# zapytanie o słowo acccbb
# zamkniętość sprawdzona - S = ['', 'a', 'ab', 'ac', 'acc', 'accc', 'b', 'ba', 'bac'], rozmiar E = ['a', 'aca', 'b', 'bc', 'c', 'ca', 'cb', 'ccb']
# hipoteza:
# (0,a) --> '0',4
# (0,b) --> '0',8
# (0,c) --> '0',0
# (1,a) --> '0',4
# (1,b) --> '0',8
# (1,c) --> '0',2
# (2,a) --> '0',4
# (2,b) --> '0',8
# (2,c) --> '0',5
# (3,a) --> '0',7
# (3,b) --> '0',8
# (3,c) --> '1',0
# (4,a) --> '0',4
# (4,b) --> '0',3
# (4,c) --> '0',1
# (5,a) --> '0',4
# (5,b) --> '1',8
# (5,c) --> '0',0
# (6,a) --> '1',4
# (6,b) --> '0',8
# (6,c) --> '0',2
# (7,a) --> '0',4
# (7,b) --> '0',3
# (7,c) --> '0',6
# (8,a) --> '0',7
# (8,b) --> '0',8
# (8,c) --> '0',0
# kontrprzyklad = cacab
# zapytanie o słowo acccbab
# zapytanie o słowo acccbcab
# zapytanie o słowo acccbacab
# S = ['', 'a', 'ab', 'ac', 'acc', 'accc', 'b', 'ba', 'bac'], rozmiar E = ['a', 'ab', 'aca', 'acab', 'b', 'bc', 'c', 'ca', 'cab', 'cb', 'ccb']
# zapytanie o słowo acacccb
# zapytanie o słowo acacacccb
# zamkniętość sprawdzona - S = ['', 'a', 'ab', 'ac', 'aca', 'acac', 'acaca', 'acc', 'accc', 'b', 'ba', 'bac', 'c'], rozmiar E = ['a', 'ab', 'aca', 'acab', 'b', 'bc', 'c', 'ca', 'cab', 'cb', 'ccb']
# hipoteza:
# (0,a) --> '0',7
# (0,b) --> '0',12
# (0,c) --> '0',6
# (1,a) --> '0',2
# (1,b) --> '0',12
# (1,c) --> '0',3
# (2,a) --> '0',7
# (2,b) --> '0',5
# (2,c) --> '0',8
# (3,a) --> '0',2
# (3,b) --> '0',12
# (3,c) --> '0',9
# (4,a) --> '0',7
# (4,b) --> '1',5
# (4,c) --> '0',8
# (5,a) --> '0',11
# (5,b) --> '0',12
# (5,c) --> '1',6
# (6,a) --> '0',2
# (6,b) --> '0',12
# (6,c) --> '0',6
# (7,a) --> '0',7
# (7,b) --> '0',5
# (7,c) --> '0',1
# (8,a) --> '0',4
# (8,b) --> '0',12
# (8,c) --> '0',3
# (9,a) --> '0',2
# (9,b) --> '1',12
# (9,c) --> '0',6
# (10,a) --> '1',2
# (10,b) --> '0',12
# (10,c) --> '0',3
# (11,a) --> '0',7
# (11,b) --> '0',5
# (11,c) --> '0',10
# (12,a) --> '0',11
# (12,b) --> '0',12
# (12,c) --> '0',6
# kontrprzykłady: [3, 4, 5, 5], cnt = [15, 5]
# # stanów = 13
