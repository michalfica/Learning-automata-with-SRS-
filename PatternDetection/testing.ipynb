# %% [markdown]
# ## Przykłady wykrywania wzorców - badanie dlaczego stopniowe uczenie jest lepsze

# %%
from importlib import reload
import copy
import sys

sys.path.append("../")

# %%
import utils.InferringMM, utils.OracleDFA, utils.Mealymachine, PatternDetection.PatterndetectionMM 

reload(utils.InferringMM)
reload(utils.OracleDFA)
reload(utils.Mealymachine)
reload(PatternDetection.PatterndetectionMM)

from utils.InferringMM import *
from utils.OracleDFA import OracleDFA
from PatternDetection.PatterndetectionMM import PatternMM

# %%
def run_learning_process(_mm, oracle=None, debug=False):
    learn_mm = InferringMM(_mm, oracle, debug=debug)
    mm, cnt, cnt_ex = learn_mm.run(counterexamples=True)
    print(f"kontrprzykłady: {cnt_ex}, cnt = {cnt}")
    return copy.deepcopy(mm)


def find_minm_mm(_mm, debug=False):
    learn_mm = InferringMM(_mm, debug=debug)
    mm, _, _ = learn_mm.run(counterexamples=True)
    return copy.deepcopy(mm)

# %% [markdown]
# ### Pierwszy przykład

# %%
in_a, out_a = ["a", "b", "c"], ["0", "1"]

mm_1 = PatternMM(["abc"], in_a, out_a)
mm_1 = run_learning_process(copy.deepcopy(mm_1), debug=True)
mm_1.print_states()
# Out:
# S = [''], rozmiar E = ['a', 'b', 'c']
# zamkniętość sprawdzona - S = [''], rozmiar E = ['a', 'b', 'c']
# hipoteza:
# (0,a) --> '0',0
# (0,b) --> '0',0
# (0,c) --> '0',0
# kontrprzyklad = abc
# S = [''], rozmiar E = ['a', 'b', 'bc', 'c']
# zamkniętość sprawdzona - S = ['', 'a', 'ab'], rozmiar E = ['a', 'b', 'bc', 'c']
# hipoteza:
# (0,a) --> '0',1
# (0,b) --> '0',0
# (0,c) --> '0',0
# (1,a) --> '0',1
# (1,b) --> '0',2
# (1,c) --> '0',0
# (2,a) --> '0',1
# (2,b) --> '0',0
# (2,c) --> '1',0
# kontrprzykłady: [3], cnt = [37, 2]
# # stanów = 3

# %%
mm_2 = PatternMM(["abc", "baca"], in_a, out_a)
mm_2 = run_learning_process(copy.deepcopy(mm_2), oracle=mm_1, debug=True)
mm_2.print_states()
# Out:
# S = [''], rozmiar E = ['a', 'b', 'c']
# zamkniętość sprawdzona - S = [''], rozmiar E = ['a', 'b', 'c']
# hipoteza:
# (0,a) --> '0',0
# (0,b) --> '0',0
# (0,c) --> '0',0
# kontrprzyklad = abc
# S = [''], rozmiar E = ['a', 'b', 'bc', 'c']
# zamkniętość sprawdzona - S = ['', 'a', 'ab'], rozmiar E = ['a', 'b', 'bc', 'c']
# hipoteza:
# (0,a) --> '0',1
# (0,b) --> '0',0
# (0,c) --> '0',0
# (1,a) --> '0',1
# (1,b) --> '0',2
# (1,c) --> '0',0
# (2,a) --> '0',1
# (2,b) --> '0',0
# (2,c) --> '1',0
# kontrprzyklad = baca
# zapytanie o słowo baca
# zapytanie o słowo abaca
# zapytanie o słowo abbaca
# S = ['', 'a', 'ab'], rozmiar E = ['a', 'aca', 'b', 'bc', 'c', 'ca']
# zapytanie o słowo bbaca
# zapytanie o słowo ababaca
# zapytanie o słowo abacaca
# zapytanie o słowo abacab
# zapytanie o słowo abacaaca
# zapytanie o słowo abacabc
# zapytanie o słowo abacaa
# zapytanie o słowo abacac
# zapytanie o słowo abacbaca
# zamkniętość sprawdzona - S = ['', 'a', 'ab', 'aba', 'abac', 'b'], rozmiar E = ['a', 'aca', 'b', 'bc', 'c', 'ca']
# hipoteza:
# (0,a) --> '0',5
# (0,b) --> '0',2
# (0,c) --> '0',0
# (1,a) --> '0',4
# (1,b) --> '0',2
# (1,c) --> '1',0
# (2,a) --> '0',4
# (2,b) --> '0',2
# (2,c) --> '0',0
# (3,a) --> '1',5
# (3,b) --> '0',2
# (3,c) --> '0',0
# (4,a) --> '0',5
# (4,b) --> '0',1
# (4,c) --> '0',3
# (5,a) --> '0',5
# (5,b) --> '0',1
# (5,c) --> '0',0
# kontrprzykłady: [3, 4], cnt = [12, 3]
# # stanów = 6

# %%
mm_3 = PatternMM(["abc", "baca", "cacab"], in_a, out_a)
mm_3 = run_learning_process(copy.deepcopy(mm_3), oracle=mm_2, debug=True)
mm_3.print_states()
# Out:
# S = [''], rozmiar E = ['a', 'b', 'c']
# zamkniętość sprawdzona - S = [''], rozmiar E = ['a', 'b', 'c']
# hipoteza:
# (0,a) --> '0',0
# (0,b) --> '0',0
# (0,c) --> '0',0
# kontrprzyklad = abc
# S = [''], rozmiar E = ['a', 'b', 'bc', 'c']
# zamkniętość sprawdzona - S = ['', 'a', 'ab'], rozmiar E = ['a', 'b', 'bc', 'c']
# hipoteza:
# (0,a) --> '0',1
# (0,b) --> '0',0
# (0,c) --> '0',0
# (1,a) --> '0',1
# (1,b) --> '0',2
# (1,c) --> '0',0
# (2,a) --> '0',1
# (2,b) --> '0',0
# (2,c) --> '1',0
# kontrprzyklad = baca
# S = ['', 'a', 'ab'], rozmiar E = ['a', 'aca', 'b', 'bc', 'c', 'ca']
# zamkniętość sprawdzona - S = ['', 'a', 'ab', 'aba', 'abac', 'b'], rozmiar E = ['a', 'aca', 'b', 'bc', 'c', 'ca']
# hipoteza:
# (0,a) --> '0',5
# (0,b) --> '0',2
# (0,c) --> '0',0
# (1,a) --> '0',4
# (1,b) --> '0',2
# (1,c) --> '1',0
# (2,a) --> '0',4
# (2,b) --> '0',2
# (2,c) --> '0',0
# (3,a) --> '1',5
# (3,b) --> '0',2
# (3,c) --> '0',0
# (4,a) --> '0',5
# (4,b) --> '0',1
# (4,c) --> '0',3
# (5,a) --> '0',5
# (5,b) --> '0',1
# (5,c) --> '0',0
# kontrprzyklad = cacab
# zapytanie o słowo cacab
# zapytanie o słowo abcacab
# zapytanie o słowo bcacab
# zapytanie o słowo abacacab
# zapytanie o słowo abaccacab
# zapytanie o słowo acacab
# S = ['', 'a', 'ab', 'aba', 'abac', 'b'], rozmiar E = ['a', 'ab', 'aca', 'acab', 'b', 'bc', 'c', 'ca', 'cab']
# zapytanie o słowo ccacab
# zapytanie o słowo abacacacab
# zapytanie o słowo abacacabc
# zapytanie o słowo abacaccacab
# zapytanie o słowo abacacabacab
# zapytanie o słowo abacacabb
# zapytanie o słowo abacacabab
# zapytanie o słowo abacacabca
# zapytanie o słowo abacacabaca
# zapytanie o słowo abacacabcab
# zapytanie o słowo abacacabbc
# zapytanie o słowo abacacaba
# zapytanie o słowo abacacacacab
# zamkniętość sprawdzona - S = ['', 'a', 'ab', 'aba', 'abac', 'abaca', 'abacac', 'abacaca', 'b', 'c'], rozmiar E = ['a', 'ab', 'aca', 'acab', 'b', 'bc', 'c', 'ca', 'cab']
# hipoteza:
# (0,a) --> '0',8
# (0,b) --> '0',2
# (0,c) --> '0',9
# (1,a) --> '0',7
# (1,b) --> '0',2
# (1,c) --> '1',9
# (2,a) --> '0',7
# (2,b) --> '0',2
# (2,c) --> '0',9
# (3,a) --> '1',4
# (3,b) --> '0',2
# (3,c) --> '0',9
# (4,a) --> '0',8
# (4,b) --> '0',1
# (4,c) --> '0',5
# (5,a) --> '0',6
# (5,b) --> '0',2
# (5,c) --> '0',9
# (6,a) --> '0',8
# (6,b) --> '1',1
# (6,c) --> '0',5
# (7,a) --> '0',8
# (7,b) --> '0',1
# (7,c) --> '0',3
# (8,a) --> '0',8
# (8,b) --> '0',1
# (8,c) --> '0',9
# (9,a) --> '0',4
# (9,b) --> '0',2
# (9,c) --> '0',9
# kontrprzykłady: [3, 4, 5], cnt = [19, 4]
# # stanów = 10

# %%
mm_4 = PatternMM(["abc", "baca", "cacab", "acccb"], in_a, out_a)
mm_4 = run_learning_process(copy.deepcopy(mm_4), oracle=mm_3, debug=True)
mm_4.print_states()
# Out:
# S = [''], rozmiar E = ['a', 'b', 'c']
# zamkniętość sprawdzona - S = [''], rozmiar E = ['a', 'b', 'c']
# hipoteza:
# (0,a) --> '0',0
# (0,b) --> '0',0
# (0,c) --> '0',0
# kontrprzyklad = abc
# S = [''], rozmiar E = ['a', 'b', 'bc', 'c']
# zamkniętość sprawdzona - S = ['', 'a', 'ab'], rozmiar E = ['a', 'b', 'bc', 'c']
# hipoteza:
# (0,a) --> '0',1
# (0,b) --> '0',0
# (0,c) --> '0',0
# (1,a) --> '0',1
# (1,b) --> '0',2
# (1,c) --> '0',0
# (2,a) --> '0',1
# (2,b) --> '0',0
# (2,c) --> '1',0
# kontrprzyklad = baca
# S = ['', 'a', 'ab'], rozmiar E = ['a', 'aca', 'b', 'bc', 'c', 'ca']
# zamkniętość sprawdzona - S = ['', 'a', 'ab', 'aba', 'abac', 'b'], rozmiar E = ['a', 'aca', 'b', 'bc', 'c', 'ca']
# hipoteza:
# (0,a) --> '0',5
# (0,b) --> '0',2
# (0,c) --> '0',0
# (1,a) --> '0',4
# (1,b) --> '0',2
# (1,c) --> '1',0
# (2,a) --> '0',4
# (2,b) --> '0',2
# (2,c) --> '0',0
# (3,a) --> '1',5
# (3,b) --> '0',2
# (3,c) --> '0',0
# (4,a) --> '0',5
# (4,b) --> '0',1
# (4,c) --> '0',3
# (5,a) --> '0',5
# (5,b) --> '0',1
# (5,c) --> '0',0
# kontrprzyklad = acccb
# zapytanie o słowo abacccb
# zapytanie o słowo acccb
# S = ['', 'a', 'ab', 'aba', 'abac', 'b'], rozmiar E = ['a', 'aca', 'b', 'bc', 'c', 'ca', 'cb', 'ccb']
# zapytanie o słowo abacccbc
# zapytanie o słowo abacccbb
# zapytanie o słowo abacccbca
# zapytanie o słowo abacccbaca
# zapytanie o słowo abacccbcb
# zapytanie o słowo abacccbccb
# zapytanie o słowo abacccbbc
# zapytanie o słowo abacccba
# zamkniętość sprawdzona - S = ['', 'a', 'ab', 'aba', 'abac', 'abacc', 'abaccc', 'ac', 'b'], rozmiar E = ['a', 'aca', 'b', 'bc', 'c', 'ca', 'cb', 'ccb']
# hipoteza:
# (0,a) --> '0',8
# (0,b) --> '0',4
# (0,c) --> '0',0
# (1,a) --> '0',8
# (1,b) --> '0',4
# (1,c) --> '0',6
# (2,a) --> '0',8
# (2,b) --> '1',4
# (2,c) --> '0',0
# (3,a) --> '0',7
# (3,b) --> '0',4
# (3,c) --> '1',0
# (4,a) --> '0',7
# (4,b) --> '0',4
# (4,c) --> '0',0
# (5,a) --> '1',8
# (5,b) --> '0',4
# (5,c) --> '0',6
# (6,a) --> '0',8
# (6,b) --> '0',4
# (6,c) --> '0',2
# (7,a) --> '0',8
# (7,b) --> '0',3
# (7,c) --> '0',5
# (8,a) --> '0',8
# (8,b) --> '0',3
# (8,c) --> '0',1
# kontrprzyklad = cacab
# zapytanie o słowo abacccbab
# zapytanie o słowo abacccbcab
# zapytanie o słowo abacccbacab
# S = ['', 'a', 'ab', 'aba', 'abac', 'abacc', 'abaccc', 'ac', 'b'], rozmiar E = ['a', 'ab', 'aca', 'acab', 'b', 'bc', 'c', 'ca', 'cab', 'cb', 'ccb']
# zapytanie o słowo acacccb
# zapytanie o słowo acacacccb
# zamkniętość sprawdzona - S = ['', 'a', 'ab', 'aba', 'abac', 'abacc', 'abaccc', 'ac', 'aca', 'acac', 'acaca', 'b', 'c'], rozmiar E = ['a', 'ab', 'aca', 'acab', 'b', 'bc', 'c', 'ca', 'cab', 'cb', 'ccb']
# hipoteza:
# (0,a) --> '0',11
# (0,b) --> '0',4
# (0,c) --> '0',12
# (1,a) --> '0',6
# (1,b) --> '0',4
# (1,c) --> '0',8
# (2,a) --> '0',6
# (2,b) --> '1',4
# (2,c) --> '0',12
# (3,a) --> '0',9
# (3,b) --> '0',4
# (3,c) --> '1',12
# (4,a) --> '0',9
# (4,b) --> '0',4
# (4,c) --> '0',12
# (5,a) --> '1',6
# (5,b) --> '0',4
# (5,c) --> '0',8
# (6,a) --> '0',11
# (6,b) --> '0',3
# (6,c) --> '0',10
# (7,a) --> '0',11
# (7,b) --> '1',3
# (7,c) --> '0',10
# (8,a) --> '0',6
# (8,b) --> '0',4
# (8,c) --> '0',2
# (9,a) --> '0',11
# (9,b) --> '0',3
# (9,c) --> '0',5
# (10,a) --> '0',7
# (10,b) --> '0',4
# (10,c) --> '0',8
# (11,a) --> '0',11
# (11,b) --> '0',3
# (11,c) --> '0',1
# (12,a) --> '0',6
# (12,b) --> '0',4
# (12,c) --> '0',12
# kontrprzykłady: [3, 4, 5, 5], cnt = [15, 5]
# # stanów = 13

# %%
mm_5 = PatternMM(["abc", "baca", "cacab", "acccb"], in_a, out_a)
mm_5 = run_learning_process(copy.deepcopy(mm_5), oracle=None, debug=True)
mm_5.print_states()
# Out:
# S = [''], rozmiar E = ['a', 'b', 'c']
# zamkniętość sprawdzona - S = [''], rozmiar E = ['a', 'b', 'c']
# hipoteza:
# (0,a) --> '0',0
# (0,b) --> '0',0
# (0,c) --> '0',0
# kontrprzyklad = abc
# S = [''], rozmiar E = ['a', 'b', 'bc', 'c']
# zamkniętość sprawdzona - S = ['', 'a', 'ab'], rozmiar E = ['a', 'b', 'bc', 'c']
# hipoteza:
# (0,a) --> '0',1
# (0,b) --> '0',0
# (0,c) --> '0',0
# (1,a) --> '0',1
# (1,b) --> '0',2
# (1,c) --> '0',0
# (2,a) --> '0',1
# (2,b) --> '0',0
# (2,c) --> '1',0
# kontrprzyklad = baca
# S = ['', 'a', 'ab'], rozmiar E = ['a', 'aca', 'b', 'bc', 'c', 'ca']
# zamkniętość sprawdzona - S = ['', 'a', 'ab', 'b', 'ba', 'bac'], rozmiar E = ['a', 'aca', 'b', 'bc', 'c', 'ca']
# hipoteza:
# (0,a) --> '0',5
# (0,b) --> '0',2
# (0,c) --> '0',0
# (1,a) --> '0',4
# (1,b) --> '0',2
# (1,c) --> '1',0
# (2,a) --> '0',4
# (2,b) --> '0',2
# (2,c) --> '0',0
# (3,a) --> '1',5
# (3,b) --> '0',2
# (3,c) --> '0',0
# (4,a) --> '0',5
# (4,b) --> '0',1
# (4,c) --> '0',3
# (5,a) --> '0',5
# (5,b) --> '0',1
# (5,c) --> '0',0
# kontrprzyklad = acccb
# S = ['', 'a', 'ab', 'b', 'ba', 'bac'], rozmiar E = ['a', 'aca', 'b', 'bc', 'c', 'ca', 'cb', 'ccb']
# zamkniętość sprawdzona - S = ['', 'a', 'ab', 'ac', 'acc', 'accc', 'b', 'ba', 'bac'], rozmiar E = ['a', 'aca', 'b', 'bc', 'c', 'ca', 'cb', 'ccb']
# hipoteza:
# (0,a) --> '0',7
# (0,b) --> '0',3
# (0,c) --> '0',0
# (1,a) --> '0',7
# (1,b) --> '0',3
# (1,c) --> '0',5
# (2,a) --> '0',6
# (2,b) --> '0',3
# (2,c) --> '1',0
# (3,a) --> '0',6
# (3,b) --> '0',3
# (3,c) --> '0',0
# (4,a) --> '1',7
# (4,b) --> '0',3
# (4,c) --> '0',5
# (5,a) --> '0',7
# (5,b) --> '0',3
# (5,c) --> '0',8
# (6,a) --> '0',7
# (6,b) --> '0',2
# (6,c) --> '0',4
# (7,a) --> '0',7
# (7,b) --> '0',2
# (7,c) --> '0',1
# (8,a) --> '0',7
# (8,b) --> '1',3
# (8,c) --> '0',0
# kontrprzyklad = cacab
# S = ['', 'a', 'ab', 'ac', 'acc', 'accc', 'b', 'ba', 'bac'], rozmiar E = ['a', 'ab', 'aca', 'acab', 'b', 'bc', 'c', 'ca', 'cab', 'cb', 'ccb']
# zamkniętość sprawdzona - S = ['', 'a', 'ab', 'ac', 'acc', 'accc', 'b', 'ba', 'bac', 'c', 'ca', 'cac', 'caca'], rozmiar E = ['a', 'ab', 'aca', 'acab', 'b', 'bc', 'c', 'ca', 'cab', 'cb', 'ccb']
# hipoteza:
# (0,a) --> '0',9
# (0,b) --> '0',3
# (0,c) --> '0',12
# (1,a) --> '0',4
# (1,b) --> '0',3
# (1,c) --> '0',7
# (2,a) --> '0',8
# (2,b) --> '0',3
# (2,c) --> '1',12
# (3,a) --> '0',8
# (3,b) --> '0',3
# (3,c) --> '0',12
# (4,a) --> '0',9
# (4,b) --> '0',2
# (4,c) --> '0',10
# (5,a) --> '0',9
# (5,b) --> '1',2
# (5,c) --> '0',10
# (6,a) --> '1',4
# (6,b) --> '0',3
# (6,c) --> '0',7
# (7,a) --> '0',4
# (7,b) --> '0',3
# (7,c) --> '0',11
# (8,a) --> '0',9
# (8,b) --> '0',2
# (8,c) --> '0',6
# (9,a) --> '0',9
# (9,b) --> '0',2
# (9,c) --> '0',1
# (10,a) --> '0',5
# (10,b) --> '0',3
# (10,c) --> '0',7
# (11,a) --> '0',4
# (11,b) --> '1',3
# (11,c) --> '0',12
# (12,a) --> '0',4
# (12,b) --> '0',3
# (12,c) --> '0',12
# kontrprzykłady: [3, 4, 5, 5], cnt = [336, 5]
# # stanów = 13
